# %% [markdown]
# <br><br><br>
# # Intgrate HTML & CSS to improve Jupyter Notebooks
#
# <br><br><br>

# %%
# %%capture 

# !pip install ipython

# import HTML 
from IPython.core.display import HTML

# %% [markdown]
# <br><br>
# Instead of using custom css directly in your notebooks, we can create a custom.css file in the folder where your Jupyter Notebook. Once created, define your classes as per your needs and then create a function as given below. This function will read all the classes in your notebook and apply them to your HTML elements wherever you've configured throughout the notebooks.
# <br><br>
# For more details; please feel free to visit - <a href="https://sites.google.com/view/gautamsatyndra/blog/customized-and-responsive-jupyter-notebook" target="_blank"> Responsive Jupyter-HTML Page</a>. This will provide you complete steps and help you create interactive and appealing notebooks.
# <br><br><br><br>

# %%
# calling the function for classes 

def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     /* Start wrting css rules and media queries */
#     div.verdana {
#         font-size: 30px;
#         font-weight: bold;
#         display: flex;
#         max-width: 100%;
#     }
#
#     div.bigger {
#         font-size: 20pt;
#     }
#
#     .hello {
#         max-width: 100%;
#         padding: 120px 50px 60px 50px;
#         background-color: rgba(231, 75, 96, 1);
#         border: 1px dashed #c7c6c6;
#         border-bottom: none;
#         position: relative;
#         z-index: 20;
#         overflow: hidden;
#         background: linear-gradient(to bottom right, rgb(29, 12, 56) 30%, rgba(27, 15, 73, 0.25)), #EE4A60 80%;
#         background-size: 100% 100%;
#         background-blend-mode: normal;
#         display: flex;
#         color: white;
#     }
#
#     @media screen and (max-width: 1000px) {
#         .hello {
#             flex-direction: column;
#         }
#     }
#
#     @media screen and (max-width: 1000px) {
#         .verdana {
# ...

# %% [markdown]
# <br><br>
# <div class="example-parent__div">
#     <p class="hello1">
#         Hello world!
#     </p>
#     <p class="hello1">
#         Hello world!
#     </p>
# </div>
# <br><br><br>

# %% [markdown]
# <br><br><br><br>
# ### Advanced HTML Layouts in Jupyter Notebook
#
# <br><br><br><br>

# %% [markdown]
# <div class="top-section-main__div" style="border-top: none;">
#     <div class="top-sec-img__overlay">
#         <img src="https://i.imgur.com/pFShFR1.png" >
#     </div>
#     <div class="top-sec-img__overlay-2"></div>
#     <div class="top-section-title-img__div" >
#         <div class="top-sec-heading_sm-text__div">
#             Plotly Dash Layout Design
#             <br>
#             <br>
#             <p style="line-height: 20px; margin:0; padding: 0; color:rgb(202, 201, 201); opacity: 0.9; fonts-size: 10px;" class="project-details__smalltexts">
#                 The inspiration behind this project emerged from my first instance with Plotly Dash during the certification
#                 program. With my immense curiosity and eagerness, I decided to create a multi-page analytical application
#                 and then started constructing the structure of this application while continuing with other course modules left.
#                 This opportunity provided me to take a deeper look into how Plotly Dash works.
#             </p>
#         </div>
#         <div  class="top-sec-img__div" style="visibility: hidden;">
#             <img src="https://i.imgur.com/gvTCBcj.png" class="top-sec-img__resize">
#         </div>
#     </div>
#     <p class="top-sec-date__div" style="justify-content: start;">
#         Sept'23 - Oct'23
#     </p>
# </div>

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
